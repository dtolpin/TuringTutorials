# %%
using Distributions
using Turing
using Stan

# Load data; loaded data is a list of dict named `ldastandata`
include(Pkg.dir("Turing")*"/stan-models/lda-stan.data.jl")
topicdata = ldastandata[1]

# Load model
include(Pkg.dir("Turing")*"/stan-models/lda.model.jl")
#= NOTE: loaded model is defined as below
@model ldamodel(K, V, M, N, w, doc, beta, alpha) = begin
  theta = Vector{Vector{Real}}(M)
  for m = 1:M
    theta[m] ~ Dirichlet(alpha)
  end

  phi = Vector{Vector{Real}}(K)
  for k = 1:K
    phi[k] ~ Dirichlet(beta)
  end

  phi_dot_theta = [log([dot(map(p -> p[i], phi), theta[m]) for i = 1:V]) for m=1:M]
  for n = 1:N
    Turing.acclogp!(vi, phi_dot_theta[doc[n]][w[n]])
  end
end
=#
# Out:
# ArgumentError: Package Stan not found in current path:
# - Run `import Pkg; Pkg.add("Stan")` to install the Stan package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:893
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
import Pkg; Pkg.add("Stan")
# Out:
#    Updating registry at `~/.julia/registries/General`
# ######################################################################### 100.0%
#   Resolving package versions...
#   Installed LaTeXStrings ─────────── v1.2.1
#   Installed MCMCChains ───────────── v4.7.3
#   Installed DiffEqSensitivity ────── v6.43.1
#   Installed Bijectors ────────────── v0.8.13
#   Installed Flux ─────────────────── v0.12.1
#   Installed Weave ────────────────── v0.10.7
#   Installed StatsFuns ────────────── v0.9.7
#   Installed Documenter ───────────── v0.26.3
#   Installed Plots ────────────────── v1.11.2
#   Installed Zygote ───────────────── v0.6.8
#   Installed Reexport ─────────────── v1.0.0
#   Installed DiffEqBase ───────────── v6.58.0
#   Installed StanDiagnose ─────────── v2.2.4
#   Installed NNlib ────────────────── v0.7.17
#   Installed GLM ──────────────────── v1.4.1
#   Installed DataFrames ───────────── v0.22.7
#   Installed StanBase ─────────────── v2.2.6
#   Installed TimerOutputs ─────────── v0.5.8
#   Installed Latexify ─────────────── v0.14.12
#   Installed Requires ─────────────── v1.1.3
#   Installed Conda ────────────────── v1.5.1
#   Installed StochasticDiffEq ─────── v6.33.1
#   Installed AbstractAlgebra ──────── v0.15.1
#   Installed Unitful ──────────────── v1.7.0
#   Installed SteadyStateDiffEq ────── v1.6.2
#   Installed TableTraits ──────────── v1.0.1
#   Installed GPUArrays ────────────── v6.2.1
#   Installed StructTypes ──────────── v1.5.2
#   Installed NLSolversBase ────────── v7.8.0
#   Installed Optim ────────────────── v1.3.0
#   Installed RecursiveArrayTools ──── v2.11.1
#   Installed ChainRules ───────────── v0.7.57
#   Installed DistributionsAD ──────── v0.6.21
#   Installed Turing ───────────────── v0.15.12
#   Installed CategoricalArrays ────── v0.9.5
#   Installed StanDump ─────────────── v0.2.0
#   Installed BandedMatrices ───────── v0.16.8
#   Installed StanVariational ──────── v2.2.4
#   Installed StanOptimize ─────────── v2.2.4
#   Installed DiffEqNoiseProcess ───── v5.7.1
#   Installed Tables ───────────────── v1.4.1
#   Installed OffsetArrays ─────────── v1.6.2
#   Installed SymbolicUtils ────────── v0.9.4
#   Installed FileIO ───────────────── v1.6.5
#   Installed LoggingExtras ────────── v0.4.6
#   Installed DocStringExtensions ──── v0.8.4
#   Installed Showoff ──────────────── v1.0.2
#   Installed ForwardDiff ──────────── v0.10.17
#   Installed SciMLBase ────────────── v1.10.1
#   Installed MLJModelInterface ────── v0.4.1
#   Installed IntervalSets ─────────── v0.5.3
#   Installed Parsers ──────────────── v1.1.0
#   Installed DiffEqCallbacks ──────── v2.16.1
#   Installed RecipesPipeline ──────── v0.3.2
#   Installed Functors ─────────────── v0.2.1
#   Installed Colors ───────────────── v0.12.7
#   Installed Transducers ──────────── v0.4.62
#   Installed Qt5Base_jll ──────────── v5.15.2+0
#   Installed Symbolics ────────────── v0.1.14
#   Installed Tracker ──────────────── v0.2.16
#   Installed GeometryBasics ───────── v0.3.10
#   Installed ChainRulesCore ───────── v0.9.37
#   Installed StatisticalTraits ────── v0.1.1
#   Installed DelayDiffEq ──────────── v5.29.1
#   Installed LabelledArrays ───────── v1.6.0
#   Installed ExponentialUtilities ─── v1.8.1
#   Installed ModelingToolkit ──────── v5.14.0
#   Installed Compat ───────────────── v3.26.0
#   Installed ColorSchemes ─────────── v3.11.0
#   Installed ColorTypes ───────────── v0.10.12
#   Installed DynamicPPL ───────────── v0.10.10
#   Installed AbstractMCMC ─────────── v2.5.0
#   Installed AbstractPPL ──────────── v0.1.2
#   Installed GR_jll ───────────────── v0.57.1+0
#   Installed ParameterizedFunctions ─ v5.10.0
#   Installed GLFW_jll ─────────────── v3.3.3+0
#   Installed StanSample ───────────── v3.0.10
#   Installed Stan ─────────────────── v6.3.2
#   Installed OrdinaryDiffEq ───────── v5.52.2
#   Installed GR ───────────────────── v0.57.1
#   Installed LatinHypercubeSampling ─ v1.8.0
#   Installed MonteCarloMeasurements ─ v0.10.1
# Updating `~/Work/probprog/TuringTutorials/Project.toml`
#   [76274a88] + Bijectors v0.8.13
#   [1624bea9] + ConjugatePriors v0.4.0
#   [a93c6f00] + DataFrames v0.22.7
#   [2b5f629d] + DiffEqBase v6.58.0
#   [ebbdde9d] + DiffEqBayes v2.23.0
#   [41bf760c] + DiffEqSensitivity v6.43.1
#   [0c46a032] + DifferentialEquations v6.16.0
#   [b4f34e82] + Distances v0.9.2
#   [31c24e10] + Distributions v0.23.12
#   [e30172f5] + Documenter v0.26.3
#   [587475ba] + Flux v0.12.1
#   [38e38edf] + GLM v1.4.1
#   [b964fa9f] + LaTeXStrings v1.2.1
#   [c7f686f2] + MCMCChains v4.7.3
#   [cc2ba9b6] + MLDataUtils v0.5.3
#   [872c559c] + NNlib v0.7.17
#   [91a5bcdd] + Plots v1.11.2
#   [d330b81b] + PyPlot v2.9.0
#   [ce6b1742] + RDatasets v0.7.4
#   [682df890] + Stan v6.3.2
#   [4c63d2b9] + StatsFuns v0.9.7
#   [f3b207a7] + StatsPlots v0.14.19
#   [fce5fe82] + Turing v0.15.12
#   [44d3d7a6] + Weave v0.10.7
#   [e88e6eb3] + Zygote v0.6.8
# Updating `~/Work/probprog/TuringTutorials/Manifest.toml`
#   [c3fe647b] + AbstractAlgebra v0.15.1
#   [621f4979] + AbstractFFTs v1.0.1
#   [80f14c24] + AbstractMCMC v2.5.0
#   [7a57a42e] + AbstractPPL v0.1.2
#   [1520ce14] + AbstractTrees v0.3.4
#   [79e6a3ab] + Adapt v3.2.0
#   [0bf59076] + AdvancedHMC v0.2.27
#   [5b7e9947] + AdvancedMH v0.5.7
#   [576499cb] + AdvancedPS v0.1.0
#   [b5ca4192] + AdvancedVI v0.1.1
#   [f5f396d3] + ApproxBayes v0.3.2
#   [dce04be8] + ArgCheck v2.1.0
#   [ec485272] + ArnoldiMethod v0.1.0
#   [7d9fca2a] + Arpack v0.4.0
#   [68821587] + Arpack_jll v3.5.0+3
#   [4fba245c] + ArrayInterface v2.14.17
#   [4c555306] + ArrayLayouts v0.4.11
#   [56f22d72] + Artifacts v1.3.0
#   [13072b0f] + AxisAlgorithms v1.0.0
#   [39de3d68] + AxisArrays v0.4.3
#   [ab4f0b2a] + BFloat16s v0.1.0
#   [aae01518] + BandedMatrices v0.16.8
#   [198e06fe] + BangBang v0.3.30
#   [6e4b80f9] + BenchmarkTools v0.5.0
#   [76274a88] + Bijectors v0.8.13
#   [764a87c0] + BoundaryValueDiffEq v2.7.1
#   [6e34b625] + Bzip2_jll v1.0.6+5
#   [fa961155] + CEnum v0.4.1
#   [336ed68f] + CSV v0.8.4
#   [052768ef] + CUDA v2.4.1
#   [83423d85] + Cairo_jll v1.16.0+6
#   [324d7699] + CategoricalArrays v0.9.5
#   [082447d4] + ChainRules v0.7.57
#   [d360d2e6] + ChainRulesCore v0.9.37
#   [aaaa29a8] + Clustering v0.14.2
#   [944b1d66] + CodecZlib v0.7.0
#   [35d6a980] + ColorSchemes v3.11.0
#   [3da002f7] + ColorTypes v0.10.12
#   [5ae59095] + Colors v0.12.7
#   [861a8166] + Combinatorics v1.0.2
#   [38540f10] + CommonSolve v0.2.0
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v3.26.0
#   [e66e0078] + CompilerSupportLibraries_jll v0.3.4+0
#   [a33af91c] + CompositionsBase v0.1.0
#   [8f4d0f93] + Conda v1.5.1
#   [1624bea9] + ConjugatePriors v0.4.0
#   [88cd18e8] + ConsoleProgressMonitor v0.1.2
#   [187b0558] + ConstructionBase v1.1.0
#   [d38c429a] + Contour v0.5.7
#   [a8cc5b0e] + Crayons v4.0.4
#   [9a962f9c] + DataAPI v1.6.0
#   [a93c6f00] + DataFrames v0.22.7
#   [864edb3b] + DataStructures v0.18.9
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [e7dc6d0d] + DataValues v0.4.13
#   [244e2a9f] + DefineSingletons v0.1.1
#   [bcd4f6db] + DelayDiffEq v5.29.1
#   [2b5f629d] + DiffEqBase v6.58.0
#   [ebbdde9d] + DiffEqBayes v2.23.0
#   [459566f4] + DiffEqCallbacks v2.16.1
#   [5a0ffddc] + DiffEqFinancial v2.4.0
#   [c894b116] + DiffEqJump v6.13.0
#   [77a26b50] + DiffEqNoiseProcess v5.7.1
#   [055956cb] + DiffEqPhysics v3.9.0
#   [41bf760c] + DiffEqSensitivity v6.43.1
#   [163ba53b] + DiffResults v1.0.3
#   [b552c78f] + DiffRules v1.0.2
#   [0c46a032] + DifferentialEquations v6.16.0
#   [c619ae07] + DimensionalPlotRecipes v1.2.0
#   [b4f34e82] + Distances v0.9.2
#   [31c24e10] + Distributions v0.23.12
#   [ced4e74d] + DistributionsAD v0.6.21
#   [ffbed154] + DocStringExtensions v0.8.4
#   [e30172f5] + Documenter v0.26.3
#   [bbc10e6e] + DynamicHMC v2.2.0
#   [366bfd00] + DynamicPPL v0.10.10
#   [5ae413db] + EarCut_jll v2.1.5+1
#   [da5c29d0] + EllipsisNotation v1.0.0
#   [cad2338a] + EllipticalSliceSampling v0.4.1
#   [2e619515] + Expat_jll v2.2.7+6
#   [d4d017d3] + ExponentialUtilities v1.8.1
#   [e2ba6199] + ExprTools v0.1.3
#   [8f5d6c58] + EzXML v1.1.0
#   [c87230d0] + FFMPEG v0.4.0
#   [b22a6f82] + FFMPEG_jll v4.3.1+4
#   [7a1cc6ca] + FFTW v1.3.2
#   [f5851436] + FFTW_jll v3.3.9+7
#   [9aa1b823] + FastClosures v0.3.2
#   [5789e2e9] + FileIO v1.6.5
#   [1a297f60] + FillArrays v0.9.7
#   [6a86dc24] + FiniteDiff v2.8.0
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [587475ba] + Flux v0.12.1
#   [a3f928ae] + Fontconfig_jll v2.13.1+14
#   [59287772] + Formatting v0.4.2
#   [f6369f11] + ForwardDiff v0.10.17
#   [d7e528f0] + FreeType2_jll v2.10.1+5
#   [559328eb] + FriBidi_jll v1.0.5+6
#   [069b7b12] + FunctionWrappers v1.1.2
#   [d9f16b24] + Functors v0.2.1
#   [0656b61e] + GLFW_jll v3.3.3+0
#   [38e38edf] + GLM v1.4.1
#   [0c68f7d7] + GPUArrays v6.2.1
#   [61eb1bfa] + GPUCompiler v0.8.3
#   [28b8d3ca] + GR v0.57.1
#   [d2c73de3] + GR_jll v0.57.1+0
#   [5c1252a2] + GeometryBasics v0.3.10
#   [78b55507] + Gettext_jll v0.20.1+7
#   [7746bdde] + Glib_jll v2.59.0+4
#   [af5da776] + GlobalSensitivity v1.0.0
#   [42e2da0e] + Grisu v1.0.0
#   [cd3eb016] + HTTP v0.9.5
#   [eafb193a] + Highlights v0.4.5
#   [0e44f5e4] + Hwloc v1.3.0
#   [e33a78d0] + Hwloc_jll v2.4.1+0
#   [b5f81e59] + IOCapture v0.1.1
#   [7869d1d1] + IRTools v0.4.2
#   [615f187c] + IfElse v0.1.0
#   [d25df0c9] + Inflate v0.1.2
#   [83e8ac13] + IniFile v0.5.0
#   [22cec73e] + InitialValues v0.2.10
#   [505f98c9] + InplaceOps v0.3.0
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [a98d9a8b] + Interpolations v0.13.1
#   [8197267c] + IntervalSets v0.5.3
#   [41ab1584] + InvertedIndices v1.0.0
#   [c8e1da08] + IterTools v1.3.0
#   [42fd0dbc] + IterativeSolvers v0.9.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.2.0
#   [682c06a0] + JSON v0.21.1
#   [aacddb02] + JpegTurbo_jll v2.0.1+3
#   [e5e0dc1b] + Juno v0.8.4
#   [5ab0869b] + KernelDensity v0.6.2
#   [c1c5ebd0] + LAME_jll v3.100.0+3
#   [929cbde3] + LLVM v3.6.0
#   [dd4b983a] + LZO_jll v2.10.0+3
#   [b964fa9f] + LaTeXStrings v1.2.1
#   [2ee39098] + LabelledArrays v1.6.0
#   [23fbe1c1] + Latexify v0.14.12
#   [a5e1c1ea] + LatinHypercubeSampling v1.8.0
#   [73f95e8e] + LatticeRules v0.0.1
#   [4af54fe1] + LazyArtifacts v1.3.0
#   [7f8f8fb0] + LearnBase v0.3.0
#   [1d6d02ad] + LeftChildRightSiblingTrees v0.1.2
#   [dd192d2f] + LibVPX_jll v1.9.0+1
#   [e9f186c6] + Libffi_jll v3.2.1+4
#   [d4300ac3] + Libgcrypt_jll v1.8.5+4
#   [7e76a0d4] + Libglvnd_jll v1.3.0+3
#   [7add5ba3] + Libgpg_error_jll v1.36.0+3
#   [94ce4f54] + Libiconv_jll v1.16.0+7
#   [4b2f31a3] + Libmount_jll v2.34.0+3
#   [6f1fad26] + Libtask v0.5.1
#   [3ae2931a] + Libtask_jll v0.4.2+0
#   [89763e89] + Libtiff_jll v4.1.0+2
#   [38a345b3] + Libuuid_jll v2.34.0+7
#   [093fc24a] + LightGraphs v1.3.5
#   [d3d80556] + LineSearches v7.1.1
#   [6fdf6af0] + LogDensityProblems v0.10.4
#   [e6f89c97] + LoggingExtras v0.4.6
#   [bdcacae8] + LoopVectorization v0.10.0
#   [c7f686f2] + MCMCChains v4.7.3
#   [d00139f3] + METIS_jll v5.1.0+5
#   [856f044c] + MKL_jll v2021.1.1+1
#   [9920b226] + MLDataPattern v0.5.4
#   [cc2ba9b6] + MLDataUtils v0.5.3
#   [e80e1ace] + MLJModelInterface v0.4.1
#   [66a33bbf] + MLLabelUtils v0.5.5
#   [1914dd2f] + MacroTools v0.5.6
#   [dbb5928d] + MappedArrays v0.3.0
#   [739be429] + MbedTLS v1.0.3
#   [c8ffd9c3] + MbedTLS_jll v2.16.8+1
#   [442fdcdd] + Measures v0.3.1
#   [e89f7d12] + Media v0.5.0
#   [128add7d] + MicroCollections v0.1.0
#   [e1d29d7a] + Missings v0.4.5
#   [78c3b35d] + Mocking v0.7.1
#   [961ee093] + ModelingToolkit v5.14.0
#   [0987c9cc] + MonteCarloMeasurements v0.10.1
#   [46d2c3a1] + MuladdMacro v0.2.2
#   [f9640e96] + MultiScaleArrays v1.8.1
#   [6f286f6a] + MultivariateStats v0.8.0
#   [ffc61752] + Mustache v1.0.10
#   [d41bc354] + NLSolversBase v7.8.0
#   [2774e3e8] + NLsolve v4.5.1
#   [872c559c] + NNlib v0.7.17
#   [77ba4419] + NaNMath v0.3.5
#   [86f7a689] + NamedArrays v0.9.4
#   [c020b1a1] + NaturalSort v1.0.0
#   [b8a86587] + NearestNeighbors v0.4.8
#   [ca575930] + NetworkOptions v1.2.0
#   [8913a72c] + NonlinearSolve v0.3.8
#   [510215fc] + Observables v0.3.3
#   [6fe1bfb0] + OffsetArrays v1.6.2
#   [e7412a2a] + Ogg_jll v1.3.4+2
#   [4536629a] + OpenBLAS_jll v0.3.9+5
#   [458c3c95] + OpenSSL_jll v1.1.1+6
#   [efe28fd5] + OpenSpecFun_jll v0.5.3+4
#   [429524aa] + Optim v1.3.0
#   [91d4177d] + Opus_jll v1.3.1+3
#   [bac558e1] + OrderedCollections v1.4.0
#   [1dea7af3] + OrdinaryDiffEq v5.52.2
#   [2f80f16e] + PCRE_jll v8.42.0+4
#   [90014a1f] + PDMats v0.10.1
#   [65888b18] + ParameterizedFunctions v5.10.0
#   [d96e819e] + Parameters v0.12.2
#   [69de0a69] + Parsers v1.1.0
#   [30392449] + Pixman_jll v0.40.0+0
#   [ccf2f8ad] + PlotThemes v2.0.1
#   [995b91a9] + PlotUtils v1.0.10
#   [91a5bcdd] + Plots v1.11.2
#   [e409e4f3] + PoissonRandom v0.4.0
#   [2dfb63ee] + PooledArrays v1.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [08abe8d2] + PrettyTables v0.11.1
#   [33c8b6b6] + ProgressLogging v0.1.4
#   [92933f4c] + ProgressMeter v1.5.0
#   [438e738f] + PyCall v1.92.2
#   [d330b81b] + PyPlot v2.9.0
#   [ea2cea3b] + Qt5Base_jll v5.15.2+0
#   [1fd47b50] + QuadGK v2.4.1
#   [8a4e6c94] + QuasiMonteCarlo v0.2.2
#   [df47a6cb] + RData v0.7.3
#   [ce6b1742] + RDatasets v0.7.4
#   [74087812] + Random123 v1.3.1
#   [fb686558] + RandomExtensions v0.4.3
#   [e6cf234a] + RandomNumbers v1.4.0
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.0
#   [3cdcf5f2] + RecipesBase v1.1.1
#   [01d81517] + RecipesPipeline v0.3.2
#   [731186ca] + RecursiveArrayTools v2.11.1
#   [f2c3362d] + RecursiveFactorization v0.1.11
#   [189a3867] + Reexport v1.0.0
#   [ae029012] + Requires v1.1.3
#   [ae5879a3] + ResettableStacks v1.1.0
#   [37e2e3b7] + ReverseDiff v1.7.0
#   [79098fc4] + Rmath v0.6.1
#   [f50d1b31] + Rmath_jll v0.2.2+2
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.1
#   [476501e8] + SLEEFPirates v0.6.8
#   [1bc83da4] + SafeTestsets v0.0.1
#   [0bca4576] + SciMLBase v1.10.1
#   [321657f4] + ScientificTypes v1.1.1
#   [6c6a2e73] + Scratch v1.0.3
#   [91c51154] + SentinelArrays v1.2.16
#   [efcf1570] + Setfield v0.7.0
#   [1277b4bf] + ShiftedArrays v1.0.0
#   [992d4aef] + Showoff v1.0.2
#   [699a6c99] + SimpleTraits v0.9.3
#   [ed01d8cd] + Sobol v1.4.0
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [47a9eef4] + SparseDiffTools v1.13.0
#   [276daf66] + SpecialFunctions v0.10.3
#   [171d559e] + SplittablesBase v0.1.13
#   [860ef19b] + StableRNGs v1.0.0
#   [682df890] + Stan v6.3.2
#   [d0ee94f6] + StanBase v2.2.6
#   [fb13fc95] + StanDiagnose v2.2.4
#   [9713c8f3] + StanDump v0.2.0
#   [fbd8da12] + StanOptimize v2.2.4
#   [c1514b29] + StanSample v3.0.10
#   [6ede68ce] + StanVariational v2.2.4
#   [90137ffa] + StaticArrays v0.12.5
#   [64bff920] + StatisticalTraits v0.1.1
#   [2913bbd2] + StatsBase v0.33.4
#   [4c63d2b9] + StatsFuns v0.9.7
#   [3eaba693] + StatsModels v0.6.21
#   [f3b207a7] + StatsPlots v0.14.19
#   [9672c7b4] + SteadyStateDiffEq v1.6.2
#   [789caeaf] + StochasticDiffEq v6.33.1
#   [09ab397b] + StructArrays v0.4.2
#   [856f2bd8] + StructTypes v1.5.2
#   [bea87d4a] + SuiteSparse_jll v5.4.0+9
#   [c3572dad] + Sundials v4.4.1
#   [fb77eaff] + Sundials_jll v5.2.0+1
#   [d1185830] + SymbolicUtils v0.9.4
#   [0c5d862f] + Symbolics v0.1.14
#   [ab02a1b2] + TableOperations v1.0.0
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.4.1
#   [5d786b92] + TerminalLoggers v0.1.3
#   [8290d209] + ThreadingUtilities v0.2.3
#   [f269a46b] + TimeZones v1.5.3
#   [a759f4b9] + TimerOutputs v0.5.8
#   [9f7883ad] + Tracker v0.2.16
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   [28d57a85] + Transducers v0.4.62
#   [84d833dd] + TransformVariables v0.3.11
#   [592b5752] + Trapz v2.0.2
#   [a2a6695c] + TreeViews v0.3.0
#   [fce5fe82] + Turing v0.15.12
#   [5c2747f8] + URIs v1.2.0
#   [3a884ed6] + UnPack v1.0.2
#   [1986cc42] + Unitful v1.7.0
#   [3d5dd08c] + VectorizationBase v0.16.2
#   [81def892] + VersionParsing v1.2.0
#   [19fa3120] + VertexSafeGraphs v0.1.2
#   [a2964d1f] + Wayland_jll v1.17.0+4
#   [2381bf8a] + Wayland_protocols_jll v1.18.0+4
#   [44d3d7a6] + Weave v0.10.7
#   [cc8bc4a8] + Widgets v0.6.2
#   [efce3f68] + WoodburyMatrices v0.5.3
#   [02c8fc9c] + XML2_jll v2.9.10+3
#   [aed1982a] + XSLT_jll v1.1.33+4
#   [4f6342f7] + Xorg_libX11_jll v1.6.9+4
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.9+4
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.3+4
#   [1082639a] + Xorg_libXext_jll v1.3.4+4
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.10+4
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.0+3
#   [c7cfdc94] + Xorg_libxcb_jll v1.13.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.0+4
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.2+4
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.27.0+4
#   [c5fb5394] + Xorg_xtrans_jll v1.4.0+3
#   [ddb6d928] + YAML v0.4.6
#   [a5390f91] + ZipFile v0.9.3
#   [83775a58] + Zlib_jll v1.2.11+18
#   [3161d3a3] + Zstd_jll v1.4.8+0
#   [e88e6eb3] + Zygote v0.6.8
#   [700de1a5] + ZygoteRules v0.2.1
#   [0ac62f75] + libass_jll v0.14.0+4
#   [f638f0a6] + libfdk_aac_jll v0.1.6+4
#   [b53b4c65] + libpng_jll v1.6.37+6
#   [f27f6e37] + libvorbis_jll v1.3.6+6
#   [1270edf5] + x264_jll v2020.7.14+2
#   [dfaa095f] + x265_jll v3.0.0+3
#   [d8fb68d0] + xkbcommon_jll v0.9.1+5
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [9abbd945] + Profile
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [1a1011a3] + SharedArrays
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#    Building Conda → `~/.julia/packages/Conda/tJJuN/deps/build.log`
#    Building GR ───→ `~/.julia/packages/GR/f111O/deps/build.log`

# %%
setchunksize(100)    # increase AD chunk-size to 100
# Out:
# ┌ Info: [Turing]: AD chunk size is set as 100
# └ @ Turing.Core /Users/dtolpin/.julia/packages/Turing/XLLTf/src/core/ad.jl:33
# 100

# %%
samples = sample(ldamodel(data=topicdata), NUTS(1000, 0.65))
# Out:
# UndefVarError: topicdata not defined
#
# Stacktrace:
#  [1] top-level scope at In[4]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
# Load visualization script for topic models; visualization function is called `vis_topic_res`
include(Pkg.dir("Turing")*"/stan-models/topic_model_vis_helper.jl")

@doc vis_topic_res  # show the usage of the visualization function
# Out:
# ┌ Warning: `Pkg.dir(pkgname, paths...)` is deprecated; instead, do `import Turing; joinpath(dirname(pathof(Turing)), "..", paths...)`.
# └ @ Pkg /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/Pkg/src/Pkg.jl:566
# could not open file /Users/dtolpin/.julia/packages/Turing/PyTy2/stan-models/topic_model_vis_helper.jl
#
# Stacktrace:
#  [1] include(::String) at ./client.jl:457
#  [2] top-level scope at In[5]:2
#  [3] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
vis_topic_res(samples, topicdata["K"], topicdata["V"], 1000)
# Out:
# UndefVarError: topicdata not defined
#
# Stacktrace:
#  [1] top-level scope at In[6]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
# Load data; loaded data is a list of dict named `nbstandata`
include(Pkg.dir("Turing")*"/stan-models/MoC-stan.data.jl")
topicdata2 = nbstandata[1]

# Load model
include(Pkg.dir("Turing")*"/stan-models/MoC.model.jl")
#= NOTE: loaded model is defined as below
@model nbmodel(K, V, M, N, z, w, doc, alpha, beta) = begin
  theta ~ Dirichlet(alpha)

  phi = Array{Any}(K)
  for k = 1:K
    phi[k] ~ Dirichlet(beta)
  end

  log_theta = log(theta)
  Turing.acclogp!(vi, sum(log_theta[z[1:M]]))

  log_phi = map(x->log(x), phi)
  for n = 1:N
    Turing.acclogp!(vi, log_phi[z[doc[n]]][w[n]])
  end

  phi
end

=#
# Out:
# could not open file /Users/dtolpin/.julia/packages/Turing/PyTy2/stan-models/MoC-stan.data.jl
#
# Stacktrace:
#  [1] include(::String) at ./client.jl:457
#  [2] top-level scope at In[7]:2
#  [3] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
samples2 = sample(nbmodel(data=topicdata2), NUTS(1000, 0.65))
# Out:
# UndefVarError: topicdata2 not defined
#
# Stacktrace:
#  [1] top-level scope at In[8]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
vis_topic_res(samples2, topicdata2["K"], topicdata2["V"], 1000)
# Out:
# UndefVarError: topicdata2 not defined
#
# Stacktrace:
#  [1] top-level scope at In[9]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
using ProgressMeter

# %%
x,n = 1,10
p = Progress(n)
for iter = 1:10
    x *= 2
    sleep(0.5)
    ProgressMeter.next!(p; showvalues = [(:iter,iter), (:x,x)])
end
